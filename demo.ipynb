# %%
from crosswords import *

# %%
#the list of words you want to be the answer 

words = ["rice","dog","cog","gift","lore","ant","cat","dad","mom", "guac","coat","salsa","layer","dip"]

#for now, clues are simply the answer

clues = {}
for word in words:
    clues[word]=[]
    clues[word].append(word)

fig = diag_grid_crossword(clues,7,7)

#plt.show()

fig.tight_layout()

# %%
#now let's try with a much harder set of words
words = random.sample(english_words_lower_alpha_set, 20)

clues = {}
for word in words:
    clues[word]=[]
    clues[word].append(word)

fig = diag_grid_crossword(clues,10,10)

#plt.show()

fig.tight_layout()
